# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'n_estimators':[10,100],'criterion':['poisson','squared_error','friedman_mse','absolute_error'],
            'max_features':['log2','auto','sqrt',None]}
grid=GridSearchCV(RandomForestRegressor(),param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['poisson', 'squared_error',
#                                        'friedman_mse', 'absolute_error'],
#                          'max_features': ['log2', 'auto', 'sqrt', None],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_prediction=grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_prediction)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}: 0.871083482155611

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.137628      0.007067         0.014358        0.002543
# 1        1.216818      0.033120         0.065245        0.012311
# 2        0.189859      0.023829         0.016164        0.002808
# 3        1.497439      0.024854         0.053394        0.003506
# 4        0.127422      0.005328         0.015539        0.001613
# 5        1.183015      0.011306         0.050997        0.003507
# 6        0.160652      0.009788         0.018697        0.003027
# 7        1.462521      0.047767         0.059364        0.006770
# 8        0.122650      0.005328         0.016321        0.002144
# 9        1.064934      0.018914         0.054881        0.011693
# 10       0.154202      0.007375         0.014779        0.001930
# 11       1.393243      0.040935         0.049672        0.002740
# 12       0.126700      0.013136         0.016868        0.000393
# 13       1.031796      0.014126         0.050057        0.001274
# 14       0.142871      0.005294         0.015445        0.003320
# 15       1.313444      0.033250         0.053323        0.003875
# 16       0.121140      0.001824         0.016097        0.003762
# 17       1.061122      0.009414         0.053919        0.004042
# 18       0.148187      0.007274         0.015797        0.001042
# 19       1.344080      0.022820         0.055592        0.003776
# 20       0.117335      0.009902         0.017132        0.001257
# 21       1.086996      0.027335         0.054634        0.002235
# 22       0.169578      0.021704         0.020471        0.012769
# 23       1.272242      0.027966         0.054367        0.004694
# 24       0.336803      0.007132         0.015082        0.002141
# 25       3.283109      0.130324         0.050607        0.005129
# 26       0.518507      0.020943         0.013500        0.003583
# 27       5.004775      0.167713         0.047591        0.002081
# 28       0.327829      0.017732         0.013367        0.001780
# 29       3.148098      0.123208         0.051824        0.006111
# 30       0.527537      0.019441         0.015410        0.001101
# 31       4.757340      0.454185         0.041201        0.006338
#
#    param_criterion param_max_features param_n_estimators  \
# 0          poisson               log2                 10
# 1          poisson               log2                100
# 2          poisson               auto                 10
# 3          poisson               auto                100
# 4          poisson               sqrt                 10
# 5          poisson               sqrt                100
# 6          poisson               None                 10
# 7          poisson               None                100
# 8    squared_error               log2                 10
# 9    squared_error               log2                100
# 10   squared_error               auto                 10
# 11   squared_error               auto                100
# 12   squared_error               sqrt                 10
# 13   squared_error               sqrt                100
# 14   squared_error               None                 10
# 15   squared_error               None                100
# 16    friedman_mse               log2                 10
# 17    friedman_mse               log2                100
# 18    friedman_mse               auto                 10
# 19    friedman_mse               auto                100
# 20    friedman_mse               sqrt                 10
# 21    friedman_mse               sqrt                100
# 22    friedman_mse               None                 10
# 23    friedman_mse               None                100
# 24  absolute_error               log2                 10
# 25  absolute_error               log2                100
# 26  absolute_error               auto                 10
# 27  absolute_error               auto                100
# 28  absolute_error               sqrt                 10
# 29  absolute_error               sqrt                100
# 30  absolute_error               None                 10
# 31  absolute_error               None                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'poisson', 'max_features': 'log2...           0.862523
# 1   {'criterion': 'poisson', 'max_features': 'log2...           0.866166
# 2   {'criterion': 'poisson', 'max_features': 'auto...           0.846621
# 3   {'criterion': 'poisson', 'max_features': 'auto...           0.867724
# 4   {'criterion': 'poisson', 'max_features': 'sqrt...           0.865775
# 5   {'criterion': 'poisson', 'max_features': 'sqrt...           0.865836
# 6   {'criterion': 'poisson', 'max_features': None,...           0.841206
# 7   {'criterion': 'poisson', 'max_features': None,...           0.864220
# 8   {'criterion': 'squared_error', 'max_features':...           0.865259
# 9   {'criterion': 'squared_error', 'max_features':...           0.855934
# 10  {'criterion': 'squared_error', 'max_features':...           0.857822
# 11  {'criterion': 'squared_error', 'max_features':...           0.860704
# 12  {'criterion': 'squared_error', 'max_features':...           0.844825
# 13  {'criterion': 'squared_error', 'max_features':...           0.864222
# 14  {'criterion': 'squared_error', 'max_features':...           0.836177
# 15  {'criterion': 'squared_error', 'max_features':...           0.858928
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.823415
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.864297
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.833373
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.860953
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.857894
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.868926
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.857711
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.864013
# 24  {'criterion': 'absolute_error', 'max_features'...           0.856672
# 25  {'criterion': 'absolute_error', 'max_features'...           0.855131
# 26  {'criterion': 'absolute_error', 'max_features'...           0.843595
# 27  {'criterion': 'absolute_error', 'max_features'...           0.845752
# 28  {'criterion': 'absolute_error', 'max_features'...           0.863514
# 29  {'criterion': 'absolute_error', 'max_features'...           0.856629
# 30  {'criterion': 'absolute_error', 'max_features'...           0.851726
# 31  {'criterion': 'absolute_error', 'max_features'...           0.844087
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.766869           0.764987           0.823923
# 1            0.789518           0.805473           0.831441
# 2            0.749549           0.805519           0.781310
# 3            0.768267           0.810798           0.795365
# 4            0.770344           0.784488           0.818113
# 5            0.791214           0.811314           0.834657
# 6            0.754521           0.812504           0.777329
# 7            0.768347           0.814117           0.799393
# 8            0.774966           0.798076           0.801400
# 9            0.788812           0.803529           0.826347
# 10           0.738578           0.806274           0.800797
# 11           0.765021           0.815734           0.799225
# 12           0.764179           0.782087           0.816724
# 13           0.786734           0.810555           0.828754
# 14           0.723974           0.800278           0.792292
# 15           0.763387           0.813778           0.806022
# 16           0.785426           0.792396           0.815418
# 17           0.789791           0.813715           0.823967
# 18           0.746255           0.801131           0.767902
# 19           0.760526           0.816140           0.795299
# 20           0.767340           0.796444           0.807785
# 21           0.798731           0.807315           0.826542
# 22           0.742362           0.808856           0.791055
# 23           0.773761           0.810752           0.797780
# 24           0.768547           0.787035           0.804541
# 25           0.790347           0.805788           0.826219
# 26           0.766448           0.778524           0.781733
# 27           0.777404           0.794967           0.801766
# 28           0.772349           0.755509           0.793924
# 29           0.789251           0.811193           0.828200
# 30           0.757652           0.794154           0.801194
# 31           0.781581           0.800908           0.803290
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.760141         0.795689        0.040745               21
# 1            0.768050         0.812130        0.034034                4
# 2            0.757687         0.788137        0.035172               29
# 3            0.772784         0.802988        0.035854               10
# 4            0.753856         0.798515        0.039731               17
# 5            0.773141         0.815232        0.032564                2
# 6            0.755152         0.788143        0.033897               28
# 7            0.767266         0.802669        0.035670               12
# 8            0.755161         0.798972        0.037139               16
# 9            0.770591         0.809043        0.029720                8
# 10           0.761579         0.793010        0.040958               25
# 11           0.773162         0.802769        0.034172               11
# 12           0.772113         0.795986        0.030299               20
# 13           0.773712         0.812796        0.031972                3
# 14           0.762737         0.783092        0.037702               32
# 15           0.767387         0.801901        0.034885               13
# 16           0.756653         0.794662        0.023633               22
# 17           0.768308         0.812015        0.032507                5
# 18           0.772336         0.784199        0.030169               31
# 19           0.772619         0.801108        0.035495               14
# 20           0.754879         0.796868        0.035996               19
# 21           0.777827         0.815868        0.030799                1
# 22           0.766341         0.793265        0.039287               24
# 23           0.771450         0.803551        0.033641                9
# 24           0.753019         0.793963        0.035818               23
# 25           0.772517         0.810000        0.028666                7
# 26           0.760735         0.786207        0.029704               30
# 27           0.765875         0.797153        0.027409               18
# 28           0.759852         0.789030        0.039560               27
# 29           0.770123         0.811079        0.030073                6
# 30           0.748026         0.790550        0.036768               26
# 31           0.766311         0.799236        0.026179               15

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:40
# BMI:28
# Children:2
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:1

# %%
Future_predict=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_predict))
# Out:
# Future_Prediction=[21803.2142558]
# C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
