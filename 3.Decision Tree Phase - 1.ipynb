# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['poisson','squared_error','friedman_mse','absolute_error'],
            'splitter':['random','best'],
            'max_features':['log2','auto','sqrt','None']}
grid=GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 40 fits failed out of a total of 160.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'auto' (deprecated), 'sqrt', 'log2'} or None. Got 'None' instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt', 'auto' (deprecated)} or None. Got 'None' instead.
#
# --------------------------------------------------------------------------------
# 13 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'auto' (deprecated), 'log2'} or None. Got 'None' instead.
#
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2', 'auto' (deprecated)} or None. Got 'None' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.48777177 0.63146855 0.64166226 0.64874195 0.54722797 0.5625942
#         nan        nan 0.61950343 0.63002912 0.66568219 0.67501274
#  0.55524946 0.66186191        nan        nan 0.5563899  0.67070074
#  0.65152338 0.66145503 0.66117036 0.6349958         nan        nan
#  0.59592254 0.64571198 0.67193075 0.6170969  0.60514753 0.59845872
#         nan        nan]
#   warnings.warn(
# C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['poisson', 'squared_error',
#                                        'friedman_mse', 'absolute_error'],
#                          'max_features': ['log2', 'auto', 'sqrt', 'None'],
#                          'splitter': ['random', 'best']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_prediction=grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_prediction)
print("The R_Score value for the best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_Score value for the best parameter {'criterion': 'squared_error', 'max_features': 'auto', 'splitter': 'best'}: 0.684820205032431

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.009996      0.002523         0.005438        0.002309
# 1        0.009132      0.004074         0.002770        0.002415
# 2        0.013672      0.003636         0.003377        0.000651
# 3        0.010472      0.001943         0.003507        0.002323
# 4        0.004602      0.002905         0.006615        0.003904
# 5        0.009074      0.005145         0.003419        0.002611
# 6        0.002479      0.002669         0.000000        0.000000
# 7        0.002219      0.002543         0.000000        0.000000
# 8        0.014588      0.003533         0.008427        0.000711
# 9        0.014834      0.004730         0.009111        0.005528
# 10       0.022856      0.005187         0.010936        0.001748
# 11       0.027680      0.008359         0.009263        0.002810
# 12       0.015964      0.000473         0.013076        0.004136
# 13       0.021133      0.006582         0.012810        0.003928
# 14       0.007999      0.005060         0.000000        0.000000
# 15       0.001611      0.001973         0.000000        0.000000
# 16       0.018248      0.004367         0.008671        0.000795
# 17       0.021922      0.003077         0.008016        0.000021
# 18       0.022628      0.005901         0.008062        0.005135
# 19       0.024938      0.005393         0.015832        0.005152
# 20       0.016200      0.005087         0.008398        0.000850
# 21       0.018662      0.003190         0.007716        0.005861
# 22       0.003519      0.003209         0.000000        0.000000
# 23       0.006050      0.003390         0.000000        0.000000
# 24       0.050084      0.003161         0.008858        0.001082
# 25       0.052804      0.004624         0.008238        0.004725
# 26       0.072587      0.005616         0.011489        0.004299
# 27       0.090522      0.009556         0.009034        0.001970
# 28       0.043634      0.009615         0.010326        0.003816
# 29       0.058062      0.006125         0.009618        0.003199
# 30       0.007161      0.001431         0.000000        0.000000
# 31       0.001406      0.002813         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0          poisson               log2         random
# 1          poisson               log2           best
# 2          poisson               auto         random
# 3          poisson               auto           best
# 4          poisson               sqrt         random
# 5          poisson               sqrt           best
# 6          poisson               None         random
# 7          poisson               None           best
# 8    squared_error               log2         random
# 9    squared_error               log2           best
# 10   squared_error               auto         random
# 11   squared_error               auto           best
# 12   squared_error               sqrt         random
# 13   squared_error               sqrt           best
# 14   squared_error               None         random
# 15   squared_error               None           best
# 16    friedman_mse               log2         random
# 17    friedman_mse               log2           best
# 18    friedman_mse               auto         random
# 19    friedman_mse               auto           best
# 20    friedman_mse               sqrt         random
# 21    friedman_mse               sqrt           best
# 22    friedman_mse               None         random
# 23    friedman_mse               None           best
# 24  absolute_error               log2         random
# 25  absolute_error               log2           best
# 26  absolute_error               auto         random
# 27  absolute_error               auto           best
# 28  absolute_error               sqrt         random
# 29  absolute_error               sqrt           best
# 30  absolute_error               None         random
# 31  absolute_error               None           best
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'poisson', 'max_features': 'log2...           0.720314
# 1   {'criterion': 'poisson', 'max_features': 'log2...           0.796615
# 2   {'criterion': 'poisson', 'max_features': 'auto...           0.709504
# 3   {'criterion': 'poisson', 'max_features': 'auto...           0.711653
# 4   {'criterion': 'poisson', 'max_features': 'sqrt...           0.591860
# 5   {'criterion': 'poisson', 'max_features': 'sqrt...           0.668987
# 6   {'criterion': 'poisson', 'max_features': 'None...                NaN
# 7   {'criterion': 'poisson', 'max_features': 'None...                NaN
# 8   {'criterion': 'squared_error', 'max_features':...           0.654242
# 9   {'criterion': 'squared_error', 'max_features':...           0.621423
# 10  {'criterion': 'squared_error', 'max_features':...           0.775310
# 11  {'criterion': 'squared_error', 'max_features':...           0.720034
# 12  {'criterion': 'squared_error', 'max_features':...           0.590056
# 13  {'criterion': 'squared_error', 'max_features':...           0.732046
# 14  {'criterion': 'squared_error', 'max_features':...                NaN
# 15  {'criterion': 'squared_error', 'max_features':...                NaN
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.487498
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.775686
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.672034
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.743348
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.733307
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.741985
# 22  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 23  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 24  {'criterion': 'absolute_error', 'max_features'...           0.719383
# 25  {'criterion': 'absolute_error', 'max_features'...           0.689892
# 26  {'criterion': 'absolute_error', 'max_features'...           0.793285
# 27  {'criterion': 'absolute_error', 'max_features'...           0.747464
# 28  {'criterion': 'absolute_error', 'max_features'...           0.649180
# 29  {'criterion': 'absolute_error', 'max_features'...           0.717779
# 30  {'criterion': 'absolute_error', 'max_features'...                NaN
# 31  {'criterion': 'absolute_error', 'max_features'...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.435672           0.377084           0.289961
# 1            0.531449           0.549535           0.639811
# 2            0.610211           0.669174           0.551374
# 3            0.584275           0.739741           0.576656
# 4            0.546228           0.503040           0.509038
# 5            0.677164           0.661022           0.226551
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.667003           0.583431           0.538744
# 9            0.672918           0.652050           0.619505
# 10           0.630459           0.625240           0.640715
# 11           0.571924           0.763092           0.631112
# 12           0.563351           0.647305           0.466509
# 13           0.633460           0.674099           0.693355
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 16           0.524516           0.563309           0.652032
# 17           0.622835           0.570845           0.679327
# 18           0.657743           0.718504           0.615629
# 19           0.552415           0.757591           0.583647
# 20           0.669784           0.693715           0.664912
# 21           0.642040           0.635590           0.514359
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
# 24           0.588622           0.637179           0.577821
# 25           0.666935           0.678296           0.531390
# 26           0.629936           0.707594           0.623408
# 27           0.578344           0.612897           0.499456
# 28           0.601894           0.559155           0.629247
# 29           0.710043           0.406370           0.512152
# 30                NaN                NaN                NaN
# 31                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.615829         0.487772        0.157842               24
# 1            0.639932         0.631469        0.093948               13
# 2            0.668049         0.641662        0.055130               11
# 3            0.631385         0.648742        0.066170                9
# 4            0.585974         0.547228        0.037163               23
# 5            0.579246         0.562594        0.171660               20
# 6                 NaN              NaN             NaN               25
# 7                 NaN              NaN             NaN               25
# 8            0.654097         0.619503        0.049966               15
# 9            0.584250         0.630029        0.030348               14
# 10           0.656687         0.665682        0.055855                4
# 11           0.688902         0.675013        0.067130                1
# 12           0.509026         0.555249        0.062870               22
# 13           0.576350         0.661862        0.053266                5
# 14                NaN              NaN             NaN               25
# 15                NaN              NaN             NaN               25
# 16           0.554594         0.556390        0.054700               21
# 17           0.704811         0.670701        0.070032                3
# 18           0.593707         0.651523        0.043765                8
# 19           0.670274         0.661455        0.082426                6
# 20           0.544133         0.661170        0.063323                7
# 21           0.641005         0.634996        0.072230               12
# 22                NaN              NaN             NaN               25
# 23                NaN              NaN             NaN               25
# 24           0.456608         0.595923        0.085714               19
# 25           0.662047         0.645712        0.057966               10
# 26           0.605430         0.671931        0.070056                2
# 27           0.647324         0.617097        0.081570               16
# 28           0.586261         0.605148        0.031630               17
# 29           0.645950         0.598459        0.121071               18
# 30                NaN              NaN             NaN               25
# 31                NaN              NaN             NaN               25

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:4
# BMI:56
# Children:5
# Sex Male 0 or 1:5
# Smoker Yes 0 or 1:3

# %%
Future_predict=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_predict))
# Out:
# Future_Prediction=[42112.2356]
# C:\Users\ramprasath\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
